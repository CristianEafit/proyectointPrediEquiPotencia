# %%
#Configuro el Google Colab conectandome a los datos desde la cuenta de Google
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
from itertools import product
from tqdm import tqdm
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import silhouette_score
from sklearn.cluster import DBSCAN
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from mpl_toolkits.mplot3d import Axes3D
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.decomposition import PCA
from numpy.linalg import norm, svd, det, cond
import plotly.graph_objs as go

from sklearn.model_selection import train_test_split, GridSearchCV
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %% [markdown]
# # Preparación de los datos

# %%
#1. Carga del Dataset
df = pd.read_csv('/content/gdrive/MyDrive/EAFIT/ProyectoIntegrador1/DatasetsRM/csv/all_files_E.csv')

# %%
# Eliminando columna redundante y convirtiendo la fecha
df = df.drop(columns=['Unnamed: 0'])
df['fecha'] = pd.to_datetime(df['fecha'])

# %%
# Limpieza y manejo de valores faltantes
for column in df.columns:
    if df[column].dtype == 'float64':
        df[column].fillna(df[column].mean(), inplace=True)
    elif df[column].dtype == 'object':
        df[column].fillna(df[column].mode()[0], inplace=True)

# %%
# Función para detectar outliers
def detect_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return ((data[column] < lower_bound) | (data[column] > upper_bound))

# %%
# Detección de outliers
outliers_dict = {}
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
for column in numeric_columns:
    outliers = detect_outliers_iqr(df, column)
    outliers_dict[column] = df[outliers]

print (outliers_dict)
# Out:
# {'requested_test_kv': Empty DataFrame
# Columns: [serial, mfr, fecha, requested_test_kv, test_kv, ma, watts, measured_cap, pfm, pfm_tipup, line_id, group_number, circuit, location, division, company, cct_designation, stator_kv]
# Index: [], 'test_kv': Empty DataFrame
# Columns: [serial, mfr, fecha, requested_test_kv, test_kv, ma, watts, measured_cap, pfm, pfm_tipup, line_id, group_number, circuit, location, division, company, cct_designation, stator_kv]
# Index: [], 'ma':        serial      mfr               fecha  requested_test_kv   test_kv  \
# 0      715015  Toshiba 2018-11-27 16:07:37                2.0  1.994720
# 1      715015  Toshiba 2018-11-27 16:07:37                4.0  4.015733
# 2      715015  Toshiba 2018-11-27 16:07:37                6.0  5.990353
# 3      715015  Toshiba 2018-11-27 16:07:37                8.0  8.009873
# 4      715015  Toshiba 2018-11-27 16:07:37                2.0  2.000625
# ...       ...      ...                 ...                ...       ...
# 12796  715016  Toshiba 2013-06-09 00:08:00                8.0  8.000000
# 12809  715016  Toshiba 2012-03-07 21:59:08                2.1  2.068000
# 12810  715016  Toshiba 2012-03-07 21:59:08                4.0  3.998000
# 12811  715016  Toshiba 2012-03-07 21:59:08                6.0  5.996000
# 12812  715016  Toshiba 2012-03-07 21:59:08                8.0  8.003000
#
#                 ma       watts   measured_cap       pfm  pfm_tipup  line_id  \
# 0      3572.892785  388.191193  948070.805862  1.086490   0.213581      1.0
# 1      3583.967686  458.960388  950296.254132  1.280593   0.194103      2.0
# 2      3568.703294  517.651520  947210.963886  1.450531   0.364041      3.0
# 3      3599.445462  585.986572  954618.258220  1.627991   0.541501      4.0
# 4      3562.023163  385.123230  945508.958239  1.081192   0.213581      5.0
# ...            ...         ...            ...       ...        ...      ...
# 12796  3594.900000  576.940000  953529.000000  1.600000   0.610000     20.0
# 12809  3566.200000  361.120000  946027.100000  1.010000   0.213581      1.0
# 12810  3576.300000  434.690000  948717.800000  1.220000   0.210000      2.0
# 12811  3586.100000  505.650000  951318.900000  1.410000   0.400000      3.0
# 12812  3593.700000  577.550000  953668.400000  1.610000   0.600000      4.0
#
#        group_number      circuit   location         division  \
# 0                 0  CIRC_GND_RB  PORCE III  GUADALUPE PORCE
# 1                 0  CIRC_GND_RB  PORCE III  GUADALUPE PORCE
# 2                 0  CIRC_GND_RB  PORCE III  GUADALUPE PORCE
# 3                 0  CIRC_GND_RB  PORCE III  GUADALUPE PORCE
# 4                 1  CIRC_GND_RB  PORCE III  GUADALUPE PORCE
# ...             ...          ...        ...              ...
# 12796             2    Undefined  PORCE III  GUADALUPE PORCE
# 12809             0    Undefined  PORCE III  GUADALUPE PORCE
# 12810             0    Undefined  PORCE III  GUADALUPE PORCE
# 12811             0    Undefined  PORCE III  GUADALUPE PORCE
# 12812             0    Undefined  PORCE III  GUADALUPE PORCE
#
#                                  company cct_designation  stator_kv
# 0      EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 1      EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 2      EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 3      EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 4      EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# ...                                  ...             ...        ...
# 12796  EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 2       13.8
# 12809  EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 2       13.8
# 12810  EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 2       13.8
# 12811  EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 2       13.8
# 12812  EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 2       13.8
#
# [324 rows x 18 columns], 'watts':        serial          mfr               fecha  requested_test_kv   test_kv  \
# 1      715015      Toshiba 2018-11-27 16:07:37                4.0  4.015733
# 2      715015      Toshiba 2018-11-27 16:07:37                6.0  5.990353
# 3      715015      Toshiba 2018-11-27 16:07:37                8.0  8.009873
# 5      715015      Toshiba 2018-11-27 16:07:37                4.0  4.013310
# 6      715015      Toshiba 2018-11-27 16:07:37                6.0  6.001621
# ...       ...          ...                 ...                ...       ...
# 16786   14375  RADE KONCAR 2005-06-03 18:58:39                8.0  7.990000
# 16789   14375  RADE KONCAR 2005-06-03 18:58:39                6.0  6.005000
# 16790   14375  RADE KONCAR 2005-06-03 18:58:39                8.0  7.992000
# 16793   14375  RADE KONCAR 2005-06-03 18:58:39                6.0  6.003000
# 16794   14375  RADE KONCAR 2005-06-03 18:58:39                8.0  7.988000
#
#                 ma       watts   measured_cap       pfm  pfm_tipup  line_id  \
# 1      3583.967686  458.960388  950296.254132  1.280593   0.194103      2.0
# 2      3568.703294  517.651520  947210.963886  1.450531   0.364041      3.0
# 3      3599.445462  585.986572  954618.258220  1.627991   0.541501      4.0
# 5      3574.055791  456.260529  947913.207483  1.276590   0.195398      6.0
# 6      3580.474019  518.103821  950094.801055  1.447026   0.365833      7.0
# ...            ...         ...            ...       ...        ...      ...
# 16786  2202.400000  448.860000  584041.300000  2.040000   0.300000      4.0
# 16789  2201.500000  425.240000  583839.100000  1.930000   0.230000     11.0
# 16790  2204.700000  454.820000  584652.200000  2.060000   0.360000     12.0
# 16793  2199.300000  421.370000  583087.900000  1.920000   0.220000     19.0
# 16794  2200.800000  446.830000  583717.700000  2.030000   0.330000     20.0
#
#        group_number      circuit   location         division  \
# 1                 0  CIRC_GND_RB  PORCE III  GUADALUPE PORCE
# 2                 0  CIRC_GND_RB  PORCE III  GUADALUPE PORCE
# 3                 0  CIRC_GND_RB  PORCE III  GUADALUPE PORCE
# 5                 1  CIRC_GND_RB  PORCE III  GUADALUPE PORCE
# 6                 1  CIRC_GND_RB  PORCE III  GUADALUPE PORCE
# ...             ...          ...        ...              ...
# 16786             0  CIRC_GND_RB     PLAYAS          GUATAPE
# 16789             1  CIRC_GND_RB     PLAYAS          GUATAPE
# 16790             1  CIRC_GND_RB     PLAYAS          GUATAPE
# 16793             2  CIRC_GND_RB     PLAYAS          GUATAPE
# 16794             2  CIRC_GND_RB     PLAYAS          GUATAPE
#
#                                  company cct_designation  stator_kv
# 1      EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 2      EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 3      EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 5      EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 6      EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# ...                                  ...             ...        ...
# 16786                         E.E.P.P.M.        UNIDAD 3       13.8
# 16789                         E.E.P.P.M.        UNIDAD 3       13.8
# 16790                         E.E.P.P.M.        UNIDAD 3       13.8
# 16793                         E.E.P.P.M.        UNIDAD 3       13.8
# 16794                         E.E.P.P.M.        UNIDAD 3       13.8
#
# [1195 rows x 18 columns], 'measured_cap':        serial      mfr               fecha  requested_test_kv   test_kv  \
# 0      715015  Toshiba 2018-11-27 16:07:37                2.0  1.994720
# 1      715015  Toshiba 2018-11-27 16:07:37                4.0  4.015733
# 2      715015  Toshiba 2018-11-27 16:07:37                6.0  5.990353
# 3      715015  Toshiba 2018-11-27 16:07:37                8.0  8.009873
# 4      715015  Toshiba 2018-11-27 16:07:37                2.0  2.000625
# ...       ...      ...                 ...                ...       ...
# 12796  715016  Toshiba 2013-06-09 00:08:00                8.0  8.000000
# 12809  715016  Toshiba 2012-03-07 21:59:08                2.1  2.068000
# 12810  715016  Toshiba 2012-03-07 21:59:08                4.0  3.998000
# 12811  715016  Toshiba 2012-03-07 21:59:08                6.0  5.996000
# 12812  715016  Toshiba 2012-03-07 21:59:08                8.0  8.003000
#
#                 ma       watts   measured_cap       pfm  pfm_tipup  line_id  \
# 0      3572.892785  388.191193  948070.805862  1.086490   0.213581      1.0
# 1      3583.967686  458.960388  950296.254132  1.280593   0.194103      2.0
# 2      3568.703294  517.651520  947210.963886  1.450531   0.364041      3.0
# 3      3599.445462  585.986572  954618.258220  1.627991   0.541501      4.0
# 4      3562.023163  385.123230  945508.958239  1.081192   0.213581      5.0
# ...            ...         ...            ...       ...        ...      ...
# 12796  3594.900000  576.940000  953529.000000  1.600000   0.610000     20.0
# 12809  3566.200000  361.120000  946027.100000  1.010000   0.213581      1.0
# 12810  3576.300000  434.690000  948717.800000  1.220000   0.210000      2.0
# 12811  3586.100000  505.650000  951318.900000  1.410000   0.400000      3.0
# 12812  3593.700000  577.550000  953668.400000  1.610000   0.600000      4.0
#
#        group_number      circuit   location         division  \
# 0                 0  CIRC_GND_RB  PORCE III  GUADALUPE PORCE
# 1                 0  CIRC_GND_RB  PORCE III  GUADALUPE PORCE
# 2                 0  CIRC_GND_RB  PORCE III  GUADALUPE PORCE
# 3                 0  CIRC_GND_RB  PORCE III  GUADALUPE PORCE
# 4                 1  CIRC_GND_RB  PORCE III  GUADALUPE PORCE
# ...             ...          ...        ...              ...
# 12796             2    Undefined  PORCE III  GUADALUPE PORCE
# 12809             0    Undefined  PORCE III  GUADALUPE PORCE
# 12810             0    Undefined  PORCE III  GUADALUPE PORCE
# 12811             0    Undefined  PORCE III  GUADALUPE PORCE
# 12812             0    Undefined  PORCE III  GUADALUPE PORCE
#
#                                  company cct_designation  stator_kv
# 0      EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 1      EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 2      EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 3      EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 4      EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# ...                                  ...             ...        ...
# 12796  EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 2       13.8
# 12809  EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 2       13.8
# 12810  EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 2       13.8
# 12811  EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 2       13.8
# 12812  EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 2       13.8
#
# [322 rows x 18 columns], 'pfm':          serial      mfr               fecha  requested_test_kv   test_kv  \
# 13       715015  Toshiba 2018-11-27 16:07:37                4.0  3.993827
# 14       715015  Toshiba 2018-11-27 16:07:37                6.0  6.000166
# 15       715015  Toshiba 2018-11-27 16:07:37                8.0  8.019350
# 17       715015  Toshiba 2018-11-27 16:07:37                4.0  4.005605
# 18       715015  Toshiba 2018-11-27 16:07:37                6.0  6.006616
# ...         ...      ...                 ...                ...       ...
# 17250  82EU7701   Alstom 2009-09-24 19:08:15                2.0  1.999000
# 17251  82EU7701   Alstom 2009-09-24 19:08:15                4.0  4.003000
# 17252  82EU7701   Alstom 2009-09-24 19:08:15                6.0  6.003000
# 17253  82EU7701   Alstom 2009-09-24 19:08:15                8.0  8.008000
# 17266  82EU7701   Alstom 2009-08-06 20:06:15                2.0  2.000000
#
#               ma      watts  measured_cap        pfm  pfm_tipup  line_id  \
# 13     21.035844  -2.140566   5581.555440  -1.017580  -0.233103     14.0
# 14     21.014433  -2.598370   5572.824868  -1.236469  -0.451992     15.0
# 15     20.977163  -3.046452   5561.111793  -1.452271  -0.667794     16.0
# 17     19.225596  -2.116055   5099.763722  -1.100645  -0.258846     18.0
# 18     19.195941  -2.595219   5089.015431  -1.351962  -0.510163     19.0
# ...          ...        ...           ...        ...        ...      ...
# 17250  13.382000  16.197000   3522.800000  12.100000   0.213581     45.0
# 17251  13.419000  16.332000   3533.900000  12.170000   0.213581     46.0
# 17252  13.425000  16.581000   3536.200000  12.350000   0.213581     47.0
# 17253  13.441000  16.913000   3537.000000  12.580000   0.480000     48.0
# 17266  12.264000   4.349000   3251.300000   3.550000   0.213581     25.0
#
#        group_number     circuit      location         division  \
# 13                3  CIRC_UST_R     PORCE III  GUADALUPE PORCE
# 14                3  CIRC_UST_R     PORCE III  GUADALUPE PORCE
# 15                3  CIRC_UST_R     PORCE III  GUADALUPE PORCE
# 17                4  CIRC_UST_R     PORCE III  GUADALUPE PORCE
# 18                4  CIRC_UST_R     PORCE III  GUADALUPE PORCE
# ...             ...         ...           ...              ...
# 17250             5  CIRC_UST_R  GUADALUPE IV        GUADALUPE
# 17251             5  CIRC_UST_R  GUADALUPE IV        GUADALUPE
# 17252             5  CIRC_UST_R  GUADALUPE IV        GUADALUPE
# 17253             5  CIRC_UST_R  GUADALUPE IV        GUADALUPE
# 17266             3  CIRC_UST_R  GUADALUPE IV        GUADALUPE
#
#                                  company cct_designation  stator_kv
# 13     EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 14     EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 15     EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 17     EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 18     EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# ...                                  ...             ...        ...
# 17250                              EEPPM        UNIDAD 1       13.8
# 17251                              EEPPM        UNIDAD 1       13.8
# 17252                              EEPPM        UNIDAD 1       13.8
# 17253                              EEPPM        UNIDAD 1       13.8
# 17266                              EEPPM        UNIDAD 1       13.8
#
# [2984 rows x 18 columns], 'pfm_tipup':          serial      mfr               fecha  requested_test_kv   test_kv  \
# 3        715015  Toshiba 2018-11-27 16:07:37                8.0  8.009873
# 7        715015  Toshiba 2018-11-27 16:07:37                8.0  7.991639
# 11       715015  Toshiba 2018-11-27 16:07:37                8.0  7.984984
# 13       715015  Toshiba 2018-11-27 16:07:37                4.0  3.993827
# 14       715015  Toshiba 2018-11-27 16:07:37                6.0  6.000166
# ...         ...      ...                 ...                ...       ...
# 17269  82EU7701   Alstom 2009-08-06 20:06:15                8.0  8.034000
# 17281  82EU7701   Alstom 2009-05-07 13:24:31                8.0  8.007000
# 17285  82EU7701   Alstom 2009-05-07 13:24:31                8.0  8.003000
# 17289  82EU7701   Alstom 2009-05-07 13:24:31                8.0  8.005000
# 17293  82EU7701   Alstom 2009-05-07 13:24:31                8.0  8.004000
#
#                 ma       watts   measured_cap       pfm  pfm_tipup  line_id  \
# 3      3599.445462  585.986572  954618.258220  1.627991   0.541501      4.0
# 7      3590.812325  582.566772  952265.423848  1.622382   0.541189      8.0
# 11     3591.274977  589.531372  951963.869511  1.641566   0.553808     12.0
# 13       21.035844   -2.140566    5581.555440 -1.017580  -0.233103     14.0
# 14       21.014433   -2.598370    5572.824868 -1.236469  -0.451992     15.0
# ...            ...         ...            ...       ...        ...      ...
# 17269    12.284000    4.053000    3256.700000  3.300000  -0.250000     28.0
# 17281  1090.800000  218.490000  289177.000000  2.000000   1.160000      4.0
# 17285  1093.600000  218.230000  289975.700000  2.000000   1.160000     12.0
# 17289  1084.100000  220.360000  287630.800000  2.030000   1.180000     20.0
# 17293    12.165000    2.311000    3226.800000  1.900000   0.410000     28.0
#
#        group_number      circuit      location         division  \
# 3                 0  CIRC_GND_RB     PORCE III  GUADALUPE PORCE
# 7                 1  CIRC_GND_RB     PORCE III  GUADALUPE PORCE
# 11                2  CIRC_GND_RB     PORCE III  GUADALUPE PORCE
# 13                3   CIRC_UST_R     PORCE III  GUADALUPE PORCE
# 14                3   CIRC_UST_R     PORCE III  GUADALUPE PORCE
# ...             ...          ...           ...              ...
# 17269             3   CIRC_UST_R  GUADALUPE IV        GUADALUPE
# 17281             0  CIRC_GND_RB  GUADALUPE IV        GUADALUPE
# 17285             1  CIRC_GND_RB  GUADALUPE IV        GUADALUPE
# 17289             2  CIRC_GND_RB  GUADALUPE IV        GUADALUPE
# 17293             3   CIRC_UST_R  GUADALUPE IV        GUADALUPE
#
#                                  company cct_designation  stator_kv
# 3      EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 7      EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 11     EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 13     EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 14     EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# ...                                  ...             ...        ...
# 17269                              EEPPM        UNIDAD 1       13.8
# 17281                              EEPPM        UNIDAD 1       13.8
# 17285                              EEPPM        UNIDAD 1       13.8
# 17289                              EEPPM        UNIDAD 1       13.8
# 17293                              EEPPM        UNIDAD 1       13.8
#
# [4668 rows x 18 columns], 'line_id':          serial      mfr               fecha  requested_test_kv  test_kv  \
# 0        715015  Toshiba 2018-11-27 16:07:37                2.0  1.99472
# 56       715015  Toshiba 2012-02-28 18:18:17                2.0  1.99800
# 78       715015  Toshiba 2012-02-28 18:18:17                6.0  6.00400
# 79       715015  Toshiba 2012-02-28 18:18:17                8.0  7.99600
# 80       715015  Toshiba 2012-02-28 18:18:17                2.0  1.99900
# ...         ...      ...                 ...                ...      ...
# 17324  82EU7701   Alstom 2008-07-13 20:05:18                6.0  5.99800
# 17325  82EU7701   Alstom 2008-07-13 20:05:18                8.0  8.00100
# 17326  82EU7701   Alstom 2005-10-01 17:29:11                2.0  2.00000
# 17352  82EU7701   Alstom 2005-10-01 17:29:11                6.0  5.99800
# 17353  82EU7701   Alstom 2005-10-01 17:29:11                8.0  7.99700
#
#                 ma       watts   measured_cap       pfm  pfm_tipup  line_id  \
# 0      3572.892785  388.191193  948070.805862  1.086490   0.213581      1.0
# 56     3505.400000  346.570000  930700.500000  0.990000   0.213581      1.0
# 78       19.197000   -3.610000    5090.900000 -1.880000  -0.750000     43.0
# 79       19.149000   -3.650000    5079.800000 -1.910000  -0.780000     44.0
# 80       19.269000   -2.060000    5111.400000 -1.070000   0.060000     45.0
# ...            ...         ...            ...       ...        ...      ...
# 17324    11.274000    1.918000    2990.400000  1.700000   0.213581     43.0
# 17325    11.280000    1.942000    2992.000000  1.720000   0.213581     44.0
# 17326   729.815717  136.663912  192923.817077  1.836669   0.213581      1.0
# 17352    11.294000    2.207000    2996.400000  1.950000   0.213581     43.0
# 17353    11.300000    2.274000    2998.400000  2.010000   0.213581     44.0
#
#        group_number      circuit      location         division  \
# 0                 0  CIRC_GND_RB     PORCE III  GUADALUPE PORCE
# 56                0  CIRC_GND_RB     PORCE III  GUADALUPE PORCE
# 78                5   CIRC_UST_R     PORCE III  GUADALUPE PORCE
# 79                5   CIRC_UST_R     PORCE III  GUADALUPE PORCE
# 80                5   CIRC_UST_R     PORCE III  GUADALUPE PORCE
# ...             ...          ...           ...              ...
# 17324             5   CIRC_UST_R  GUADALUPE IV        GUADALUPE
# 17325             5   CIRC_UST_R  GUADALUPE IV        GUADALUPE
# 17326             0    Undefined  GUADALUPE IV        GUADALUPE
# 17352             5    Undefined  GUADALUPE IV        GUADALUPE
# 17353             5    Undefined  GUADALUPE IV        GUADALUPE
#
#                                  company cct_designation  stator_kv
# 0      EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 56     EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 78     EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 79     EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# 80     EMPRESAS PUBLICAS DE MEDELLIN EPM        UNIDAD 3       13.8
# ...                                  ...             ...        ...
# 17324                              EEPPM        UNIDAD 1       13.8
# 17325                              EEPPM        UNIDAD 1       13.8
# 17326                              EEPPM        UNIDAD 1       13.8
# 17352                              EEPPM        UNIDAD 1       13.8
# 17353                              EEPPM        UNIDAD 1       13.8
#
# [1418 rows x 18 columns], 'group_number': Empty DataFrame
# Columns: [serial, mfr, fecha, requested_test_kv, test_kv, ma, watts, measured_cap, pfm, pfm_tipup, line_id, group_number, circuit, location, division, company, cct_designation, stator_kv]
# Index: [], 'stator_kv':         serial               mfr               fecha  requested_test_kv  \
# 535    1S15P15  General Electric 2019-05-25 17:37:05                1.0
# 536    1S15P15  General Electric 2019-05-25 17:37:05                2.0
# 537    1S15P15  General Electric 2019-05-25 17:37:05                3.0
# 538    1S15P15  General Electric 2019-05-25 17:37:05                4.0
# 539    1S15P15  General Electric 2019-05-25 17:37:05                1.0
# ...        ...               ...                 ...                ...
# 15953  6638009  General Electric 2009-03-31 13:05:53                0.5
# 15954  6638009  General Electric 2009-03-31 13:05:53                0.5
# 15955  6638009  General Electric 2009-03-31 13:05:53                2.4
# 15956  6638009  General Electric 2009-03-31 13:05:53                0.5
# 15957  6638009  General Electric 2009-03-31 13:05:53                2.4
#
#         test_kv          ma       watts   measured_cap       pfm  pfm_tipup  \
# 535    0.999915  497.478560  222.621597  131842.874396  4.474999   0.213581
# 536    1.999991  498.990029  234.252762  132265.590480  4.694538   0.219539
# 537    3.001618  500.642985  245.404625  132624.670357  4.901789   0.426790
# 538    4.001358  502.171725  257.595200  133025.942262  5.129624   0.654625
# 539    0.999300  497.812837  217.469292  131969.734696  4.368495   0.213581
# ...         ...         ...         ...            ...       ...        ...
# 15953  0.500000  729.815717  136.663912  192923.817077  1.836669   0.213581
# 15954  0.500000   19.208000   14.338000    5077.200000  7.460000   0.213581
# 15955  2.400000   19.218000   14.496000    5081.200000  7.540000   0.213581
# 15956  0.500000   17.077000   12.386000    4520.700000  7.250000   0.213581
# 15957  2.400000   17.088000   12.419000    4521.400000  7.270000   0.213581
#
#          line_id  group_number      circuit   location            division  \
# 535    22.097561             0  CIRC_GND_RB  SONSON II  Area Metropolitana
# 536    22.097561             0  CIRC_GND_RB  SONSON II  Area Metropolitana
# 537    22.097561             0  CIRC_GND_RB  SONSON II  Area Metropolitana
# 538    22.097561             0  CIRC_GND_RB  SONSON II  Area Metropolitana
# 539    22.097561             1  CIRC_GND_RB  SONSON II  Area Metropolitana
# ...          ...           ...          ...        ...                 ...
# 15953  32.000000             3   CIRC_UST_R  LA INSULA           LA INSULA
# 15954  33.000000             4   CIRC_UST_R  LA INSULA           LA INSULA
# 15955  34.000000             4   CIRC_UST_R  LA INSULA           LA INSULA
# 15956  41.000000             5   CIRC_UST_R  LA INSULA           LA INSULA
# 15957  42.000000             5   CIRC_UST_R  LA INSULA           LA INSULA
#
#                              company cct_designation  stator_kv
# 535    Empresas Publicas de Medellin         UNIDAD        6.90
# 536    Empresas Publicas de Medellin         UNIDAD        6.90
# 537    Empresas Publicas de Medellin         UNIDAD        6.90
# 538    Empresas Publicas de Medellin         UNIDAD        6.90
# 539    Empresas Publicas de Medellin         UNIDAD        6.90
# ...                              ...             ...        ...
# 15953                           CHEC        UNIDAD 1       4.16
# 15954                           CHEC        UNIDAD 1       4.16
# 15955                           CHEC        UNIDAD 1       4.16
# 15956                           CHEC        UNIDAD 1       4.16
# 15957                           CHEC        UNIDAD 1       4.16
#
# [4948 rows x 18 columns]}

# %%
# Aplicando transformaciones a las columnas con outliers
#for column, count in outliers_dict.items():
#    if count > 0:
#        if (df[column] > 0).all():
#            df[column + "_log"] = np.log(df[column])
#        else:
#            df[column + "_sqrt"] = np.sqrt(df[column].abs())

# Eliminando las columnas originales con outliers
#columns_to_drop = [column for column, count in outliers_dict.items() if count > 0]
#df_transformed = df.drop(columns=columns_to_drop)

# %%
# Análisis descriptivo de las columnas transformadas
print("Análisis Descriptivo de Variables:")
print(df.describe())

# Correlación entre variables
print("\nMatriz de Correlación:")
correlation_matrix = df.corr()
print(correlation_matrix)

# Gráfico de correlación
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Mapa de Calor de Correlación")
plt.show()
# Out:
# Análisis Descriptivo de Variables:
#        requested_test_kv       test_kv            ma          watts  \
# count       17354.000000  17354.000000  17354.000000   17354.000000
# mean            4.715852      4.712992    729.815717     136.663912
# std             2.424405      2.406028    873.372180    2119.506093
# min             0.100000      0.084000      0.000000    -439.750000
# 25%             2.000000      2.001000     10.447331       0.784098
# 50%             4.000000      4.002000    371.477760      74.114000
# 75%             6.000000      6.006173   1381.813512     162.030995
# max            12.000000     12.000000  27063.400000  270494.700000
#
#         measured_cap           pfm     pfm_tipup       line_id  group_number  \
# count   17354.000000  17354.000000  17354.000000  17354.000000  17354.000000
# mean   192923.817077      1.836669      0.213581     22.097561      2.520341
# std    225259.181536      4.284171      1.333901     11.141986      1.760829
# min   -109771.000000    -92.160000    -33.000000      1.000000      0.000000
# 25%      2760.010026      0.760000      0.090000     17.000000      1.000000
# 50%     98073.554111      1.300000      0.213581     22.097561      3.000000
# 75%    366257.375000      1.840000      0.213581     27.000000      4.000000
# max    999821.900000     99.950000     89.422125     52.000000      6.000000
#
#           stator_kv
# count  17354.000000
# mean      13.175609
# std        3.134977
# min        4.160000
# 25%       13.800000
# 50%       13.800000
# 75%       13.800000
# max       18.000000
#
# Matriz de Correlación:
#                    requested_test_kv   test_kv        ma     watts  \
# requested_test_kv           1.000000  0.992272  0.063773 -0.007831
# test_kv                     0.992272  1.000000  0.064306 -0.007893
# ma                          0.063773  0.064306  1.000000  0.295747
# watts                      -0.007831 -0.007893  0.295747  1.000000
# measured_cap                0.069776  0.070357  0.972216  0.065264
# pfm                        -0.075054 -0.075601  0.006752  0.217870
# pfm_tipup                   0.034098  0.034363  0.094253  0.021650
# line_id                     0.065327  0.065311 -0.548030 -0.038587
# group_number               -0.000570 -0.003370 -0.641278 -0.044274
# stator_kv                   0.418561  0.413597  0.139761 -0.015797
#
#                    measured_cap       pfm  pfm_tipup   line_id  group_number  \
# requested_test_kv      0.069776 -0.075054   0.034098  0.065327     -0.000570
# test_kv                0.070357 -0.075601   0.034363  0.065311     -0.003370
# ma                     0.972216  0.006752   0.094253 -0.548030     -0.641278
# watts                  0.065264  0.217870   0.021650 -0.038587     -0.044274
# measured_cap           1.000000 -0.043525   0.094242 -0.562093     -0.658326
# pfm                   -0.043525  1.000000   0.373731  0.029338      0.018189
# pfm_tipup              0.094242  0.373731   1.000000 -0.061029     -0.108971
# line_id               -0.562093  0.029338  -0.061029  1.000000      0.771954
# group_number          -0.658326  0.018189  -0.108971  0.771954      1.000000
# stator_kv              0.148047 -0.213050  -0.007945  0.015745      0.006657
#
#                    stator_kv
# requested_test_kv   0.418561
# test_kv             0.413597
# ma                  0.139761
# watts              -0.015797
# measured_cap        0.148047
# pfm                -0.213050
# pfm_tipup          -0.007945
# line_id             0.015745
# group_number        0.006657
# stator_kv           1.000000
# <ipython-input-8-6e4e8aac757b>:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
# Histogramas y gráficos de caja para las columnas transformadas
numeric_transformed_columns = df.select_dtypes(include=['float64', 'int64']).columns
num_plots = len(numeric_transformed_columns)
num_rows = (num_plots // 5) + (1 if num_plots % 5 > 0 else 0)

plt.figure(figsize=(25, num_rows * 4))
for i, column in enumerate(numeric_transformed_columns, 1):
    plt.subplot(num_rows, 5, i)
    sns.histplot(df[column], kde=True)
    plt.title(f'Distribución de {column}')
    plt.xlabel('Valor')
    plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(25, num_rows * 4))
for i, column in enumerate(numeric_transformed_columns, 1):
    plt.subplot(num_rows, 5, i)
    sns.boxplot(y=df[column])
    plt.title(f'Gráfico de Caja de {column}')
    plt.xlabel('Categoría')
    plt.ylabel('Valor')

plt.tight_layout()
plt.show()

# %%
#2. Estandarizacion de columna mfr empleando diccionario

## Diccionario de mapeo de valores originales a valores deseados
mapeo = {
  'Ansal' : 'ANS',
  'General Electric' : 'GE',
  'Brown Boveri Company' : 'GMX',
  'Mitsubishi' : 'MIT',
  'ENERGOMEX' : 'ENG',
  'Rade-Koncar' : 'RK',
  'Toshiba' : 'TOS',
  'AEG Power Tool Corp.' : 'GMX',
  'Alstom' : 'ALS',
  'ASEA' : 'GMX',
  'RADE KONCAR' : 'RK',
  'Westinghouse Electric' : 'OTH',
  'TIBB' : 'GMX',
  'ABB (ASEA-Brown Boveri)' : 'GMX',
  'Koch & Sterzel' : 'OTH',
  'Hitachi' : 'HIT',
  'ASEA Inc.' : 'GMX',
  'Cenemesa' : 'OTH',
  'HITACHI' : 'HIT',
  'Raychem' : 'OTH',
  'Brush Ltd. (H-S Group)' : 'OTH',
  'HARBIN ELECTRIC MACHINERY' : 'OTH',
  'Magnetek' : 'OTH',
  'GAMESA' : 'OTH'
}

## Cambiar los valores en la columna 'mfr' utilizando el diccionario
df['mfr'] = df['mfr'].map(mapeo)

#3. Homologar valores de columna group_number
## Reemplazar los valores en la columna group_number
df['group_number'] = df['group_number'].replace({0: 'GST', 1: 'GST', 2: 'GST', 6:'GST', 3: 'UST', 4: 'UST', 5: 'UST'})

# %%
#4. Estandarizacion de valores para columna requested_text_kv (rtkv)

## Obtener los valores únicos de la columna 'requested_test_kv'
valores_rtkv = df['requested_test_kv'].unique()
#Reemplazo de valores
## Diccionario de reemplazo
diccionario_reemplazo = {
    2.5: 2.,
    2.3: 2.,
    2.4: 2.,
    3.8: 4.,
    10.4: 10.,
    10.0: 10.,
    5.9: 6.,
    6.1: 6.,
    8.1: 8.,
    8.2: 8.,
    1.9: 2.,
    7.9: 8.,
    2.1: 2.,
    9.9: 10.,
    10.3: 10.,
    10.2: 10.,
    10.4: 10.
}
df.loc[:, 'requested_test_kv'] = df['requested_test_kv'].replace(diccionario_reemplazo)

## Registros a depurar basados en la columna 'requested_test_kv' por ser no válidos para el análisis
valores_a_eliminar = [0.2, 0.5, 1.4, 1.5, 0.8, 0.1, 5.5, 7, 9 ]

## Eliminar filas con los valores especificados
df = df[~df['requested_test_kv'].isin(valores_a_eliminar)]

## Obtener los valores únicos de la columna 'requested_test_kv'
valores_rtkv = df['requested_test_kv'].unique()
valores_rtkv
# Out:
# array([ 2.,  4.,  6.,  8.,  1.,  3., 10.,  5., 12.])

# %%
#5. Eliminacion valores no válidos (0, NaN, NULL, etc)
## Contar la cantidad de NaN en df
#cantidad_nan = df.isna().sum()
#print(f"Cantidad de NaN en {'df'}: {cantidad_nan}")

columna_filtrar = 'ma'
df = df[(df[columna_filtrar] != 0) & (~df[columna_filtrar].isna())]
columna_filtrar = 'measured_cap'
df = df[(df[columna_filtrar] != 0) & (~df[columna_filtrar].isna())]
columna_filtrar = 'pfm'
df = df[(df[columna_filtrar] != 0) & (~df[columna_filtrar].isna())]

## Contar la cantidad de NaN en df
#cantidad_nan = df.isna().sum()
#print(f"Cantidad de NaN en {'df'}: {cantidad_nan}")
df.to_csv('datafiles_clean.csv')

# %% [markdown]
# # **Evaluación PCA**

# %%
##Aplicacion PCA
# Preprocesamiento: Estandarización de los datos (importante para PCA)
# Selecciona solo las columnas numéricas para PCA
numeric_df = df.select_dtypes(include=['float64', 'int64'])
scaler = StandardScaler()
scaled_data = scaler.fit_transform(numeric_df)

# Aplicación de PCA
pca = PCA(n_components=2)  # Reducir a 2 dimensiones para visualización
pca.fit(scaled_data)

# Creando el gráfico de cargas con Plotly
loadings = pca.components_.T * np.sqrt(pca.explained_variance_)
fig = go.Figure()

# Agregando las flechas de las cargas
for i, loading in enumerate(loadings):
    fig.add_trace(go.Scatter(x=[0, loading[0]], y=[0, loading[1]],
                             mode='lines+text',
                             text=[None, numeric_df.columns[i]],
                             textposition="top center",
                             line=dict(width=2, color='blue')))

# Configurando el layout del gráfico
fig.update_layout(title='Gráfico de Cargas en PCA',
                  xaxis_title='Componente Principal 1',
                  yaxis_title='Componente Principal 2',
                  showlegend=False,
                  width=800,
                  height=600)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e192a84a-3c17-4955-9782-ff5f90c340aa" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e192a84a-3c17-4955-9782-ff5f90c340aa")) {                    Plotly.newPlot(                        "e192a84a-3c17-4955-9782-ff5f90c340aa",                        [{"line":{"color":"blue","width":2},"mode":"lines+text","text":[null,"requested_test_kv"],"textposition":"top center","x":[0,0.2256411442126671],"y":[0,0.9295659942124732],"type":"scatter"},{"line":{"color":"blue","width":2},"mode":"lines+text","text":[null,"test_kv"],"textposition":"top center","x":[0,0.22564538681238214],"y":[0,0.9281029815757994],"type":"scatter"},{"line":{"color":"blue","width":2},"mode":"lines+text","text":[null,"ma"],"textposition":"top center","x":[0,0.9589300475957981],"y":[0,-0.13729800902940917],"type":"scatter"},{"line":{"color":"blue","width":2},"mode":"lines+text","text":[null,"watts"],"textposition":"top center","x":[0,0.9043772573176374],"y":[0,-0.1060461001635724],"type":"scatter"},{"line":{"color":"blue","width":2},"mode":"lines+text","text":[null,"measured_cap"],"textposition":"top center","x":[0,0.9583918748268611],"y":[0,-0.1369723363452557],"type":"scatter"},{"line":{"color":"blue","width":2},"mode":"lines+text","text":[null,"pfm"],"textposition":"top center","x":[0,0.005468098653523255],"y":[0,-0.20301641629488298],"type":"scatter"},{"line":{"color":"blue","width":2},"mode":"lines+text","text":[null,"pfm_tipup"],"textposition":"top center","x":[0,0.19675926431128288],"y":[0,-0.06970450787205364],"type":"scatter"},{"line":{"color":"blue","width":2},"mode":"lines+text","text":[null,"line_id"],"textposition":"top center","x":[0,-0.6563032245208208],"y":[0,0.25977520254917663],"type":"scatter"},{"line":{"color":"blue","width":2},"mode":"lines+text","text":[null,"stator_kv"],"textposition":"top center","x":[0,0.21005873349531437],"y":[0,0.5949953778533889],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"# ...

# %%
# Valores y vectores propios (para la identificación de proyecciones y reducción de dimensiones)
eigenvalues = pca.explained_variance_
eigenvectors = pca.components_

# Normas (para calcular varianzas globales)
eigen_norms = norm(eigenvectors, axis=1)

# Productos internos (para identificar asociaciones lineales entre variables)
# Los productos internos de los vectores propios con los datos originales
# indican cómo se proyectan los datos en los componentes principales
inner_products = np.dot(scaled_data, eigenvectors.T)

# Calculando la matriz de covarianza de los datos escalados
cov_matrix = np.cov(scaled_data, rowvar=False)

# Calculando el determinante de la matriz de covarianza
determinant_cov_matrix = np.linalg.det(cov_matrix)

# Descomposición en valores singulares (SVD)
u, s, vt = svd(scaled_data)

# Número de condición de las matrices de covarianzas (para evaluar la estabilidad numérica)
cov_matrix = np.cov(scaled_data, rowvar=False)
condition_number = cond(cov_matrix)

# %%
# Imprimiendo los resultados
print("Valores Propios:", eigenvalues)
print("Vectores Propios:", eigenvectors)
print("Normas de los Vectores Propios:", eigen_norms)
print("Productos Internos:", inner_products)
print("Determinante de la Matriz de Covarianza:", determinant_cov_matrix)
print("Descomposición en Valores Singulares:", s)
print("Número de Condición de la Matriz de Covarianza:", condition_number)
# Out:
# Valores Propios: [3.27139251 2.24190306]
# Vectores Propios: [[ 0.12475328  0.12475562  0.53017665  0.50001531  0.52987911  0.00302322
#    0.10878496 -0.36285926  0.11613802]
#  [ 0.62082874  0.61985164 -0.09169715 -0.07082495 -0.09147964 -0.13558846
#   -0.04655351  0.17349592  0.39737924]]
# Normas de los Vectores Propios: [1. 1.]
# Productos Internos: [[ 4.81510482 -2.38907661]
#  [ 5.22600209 -1.37274077]
#  [ 5.58276695 -0.36382363]
#  ...
#  [-1.97038656  0.19982569]
#  [-1.79482915  1.24771936]
#  [-1.61915917  2.29580434]]
# Determinante de la Matriz de Covarianza: 8.073649527594341e-07
# Descomposición en Valores Singulares: [236.7185721  195.9631535  156.31003486 114.05849401 100.99894582
#   96.80570111  50.8540716   11.29490402   2.17962456]
# Número de Condición de la Matriz de Covarianza: 11795.090532419475

# %% [markdown]
# PCA proporciona una herramienta valiosa para sintetizar y analizar datos complejos. Nos permite una comprensión más profunda y facilita el análisis predictivos o de diagnóstico.

# %% [markdown]
# *   En este caso, el tratamiento de datos empleando PCA nos permite identificar las variables que mayor incidencia tienen en el set de datos; se puede identificar una alta colinealidad entre las variables 'ma', 'watts' y 'measured_cap', dadas las cercanías en sus coeficientes; El método tradicional emplea siempre evaluar 'pfm' vs 'requested_test_kv', y se observa que si bien los pesos son bajos, no hay una colinealidad.
# *   Las componentes principales se construyen para ser ortogonales entre sí, lo que significa que no están correlacionadas. Sin embargo, cuando se interpreta la importancia relativa de las variables en una componente principal, la presencia de pesos similares para múltiples variables puede indicar la existencia de patrones o estructuras subyacentes en los datos.
# *   La matriz de correlacion permite llegar a la misma conclusión.
# *   De acuerdo con las prácticas de industria se decide contiuar con la evalaucion entre variables 'requested_test_kv' y 'pfm'.

# %% [markdown]
# # Ejercicios de Clusterización (1)

# %%
# Obtener el array de los valores sin repetidos
array_valores_no_repetidos = list(set(mapeo.values()))

# Imprimir el array de los valores
print(array_valores_no_repetidos)
# Out:
# ['MIT', 'ANS', 'ENG', 'OTH', 'TOS', 'RK', 'GMX', 'HIT', 'GE', 'ALS']

# %%
# Definir los arrays
array_a = ['GST', 'UST']
array_b = [6.9, 13.8, 18]
array_c = array_valores_no_repetidos
array_d = [1,2,3,4,6,8,10]

# Obtener todas las combinaciones posibles
combinaciones = list(product(array_a, array_b, array_c,array_d))

 # Mostrar el tamaño de la lista
print("Tamaño de la lista de combinaciones:", len(combinaciones))
combinaciones
# Imprimir las combinaciones
#print(combinaciones)
# Out:
# Tamaño de la lista de combinaciones: 420
# [('GST', 6.9, 'MIT', 1),
#  ('GST', 6.9, 'MIT', 2),
#  ('GST', 6.9, 'MIT', 3),
#  ('GST', 6.9, 'MIT', 4),
#  ('GST', 6.9, 'MIT', 6),
#  ('GST', 6.9, 'MIT', 8),
#  ('GST', 6.9, 'MIT', 10),
#  ('GST', 6.9, 'ANS', 1),
#  ('GST', 6.9, 'ANS', 2),
#  ('GST', 6.9, 'ANS', 3),
#  ('GST', 6.9, 'ANS', 4),
#  ('GST', 6.9, 'ANS', 6),
#  ('GST', 6.9, 'ANS', 8),
#  ('GST', 6.9, 'ANS', 10),
#  ('GST', 6.9, 'ENG', 1),
#  ('GST', 6.9, 'ENG', 2),
#  ('GST', 6.9, 'ENG', 3),
#  ('GST', 6.9, 'ENG', 4),
#  ('GST', 6.9, 'ENG', 6),
#  ('GST', 6.9, 'ENG', 8),
#  ('GST', 6.9, 'ENG', 10),
#  ('GST', 6.9, 'OTH', 1),
#  ('GST', 6.9, 'OTH', 2),
#  ('GST', 6.9, 'OTH', 3),
#  ('GST', 6.9, 'OTH', 4),
#  ('GST', 6.9, 'OTH', 6),
#  ('GST', 6.9, 'OTH', 8),
#  ('GST', 6.9, 'OTH', 10),
#  ('GST', 6.9, 'TOS', 1),
#  ('GST', 6.9, 'TOS', 2),
#  ('GST', 6.9, 'TOS', 3),
#  ('GST', 6.9, 'TOS', 4),
#  ('GST', 6.9, 'TOS', 6),
#  ('GST', 6.9, 'TOS', 8),
#  ('GST', 6.9, 'TOS', 10),
#  ('GST', 6.9, 'RK', 1),
#  ('GST', 6.9, 'RK', 2),
#  ('GST', 6.9, 'RK', 3),
#  ('GST', 6.9, 'RK', 4),
#  ('GST', 6.9, 'RK', 6),
#  ('GST', 6.9, 'RK', 8),
#  ('GST', 6.9, 'RK', 10),
#  ('GST', 6.9, 'GMX', 1),
#  ('GST', 6.9, 'GMX', 2),
#  ('GST', 6.9, 'GMX', 3),
#  ('GST', 6.9, 'GMX', 4),
#  ('GST', 6.9, 'GMX', 6),
#  ('GST', 6.9, 'GMX', 8),
#  ('GST', 6.9, 'GMX', 10),
#  ('GST', 6.9, 'HIT', 1),
#  ('GST', 6.9, 'HIT', 2),
#  ('GST', 6.9, 'HIT', 3),
#  ('GST', 6.9, 'HIT', 4),
#  ('GST', 6.9, 'HIT', 6),
#  ('GST', 6.9, 'HIT', 8),
#  ('GST', 6.9, 'HIT', 10),
#  ('GST', 6.9, 'GE', 1),
#  ('GST', 6.9, 'GE', 2),
#  ('GST', 6.9, 'GE', 3),
#  ('GST', 6.9, 'GE', 4),
#  ('GST', 6.9, 'GE', 6),
#  ('GST', 6.9, 'GE', 8),
#  ('GST', 6.9, 'GE', 10),
#  ('GST', 6.9, 'ALS', 1),
#  ('GST', 6.9, 'ALS', 2),
#  ('GST', 6.9, 'ALS', 3),
#  ('GST', 6.9, 'ALS', 4),
#  ('GST', 6.9, 'ALS', 6),
#  ('GST', 6.9, 'ALS', 8),
#  ('GST', 6.9, 'ALS', 10),
#  ('GST', 13.8, 'MIT', 1),
#  ('GST', 13.8, 'MIT', 2),
#  ('GST', 13.8, 'MIT', 3),
#  ('GST', 13.8, 'MIT', 4),
#  ('GST', 13.8, 'MIT', 6),
#  ('GST', 13.8, 'MIT', 8),
#  ('GST', 13.8, 'MIT', 10),
#  ('GST', 13.8, 'ANS', 1),
#  ('GST', 13.8, 'ANS', 2),
#  ('GST', 13.8, 'ANS', 3),
#  ('GST', 13.8, 'ANS', 4),
#  ('GST', 13.8, 'ANS', 6),
#  ('GST', 13.8, 'ANS', 8),
#  ('GST', 13.8, 'ANS', 10),
#  ('GST', 13.8, 'ENG', 1),
#  ('GST', 13.8, 'ENG', 2),
#  ('GST', 13.8, 'ENG', 3),
#  ('GST', 13.8, 'ENG', 4),
#  ('GST', 13.8, 'ENG', 6),
#  ('GST', 13.8, 'ENG', 8),
#  ('GST', 13.8, 'ENG', 10),
#  ('GST', 13.8, 'OTH', 1),
#  ('GST', 13.8, 'OTH', 2),
#  ('GST', 13.8, 'OTH', 3),
#  ('GST', 13.8, 'OTH', 4),
#  ('GST', 13.8, 'OTH', 6),
#  ('GST', 13.8, 'OTH', 8),
#  ('GST', 13.8, 'OTH', 10),
#  ('GST', 13.8, 'TOS', 1),
#  ('GST', 13.8, 'TOS', 2),
#  ('GST', 13.8, 'TOS', 3),
#  ('GST', 13.8, 'TOS', 4),
#  ('GST', 13.8, 'TOS', 6),
#  ('GST', 13.8, 'TOS', 8),
#  ('GST', 13.8, 'TOS', 10),
#  ('GST', 13.8, 'RK', 1),
#  ('GST', 13.8, 'RK', 2),
#  ('GST', 13.8, 'RK', 3),
#  ('GST', 13.8, 'RK', 4),
#  ('GST', 13.8, 'RK', 6),
#  ('GST', 13.8, 'RK', 8),
#  ('GST', 13.8, 'RK', 10),
#  ('GST', 13.8, 'GMX', 1),
#  ('GST', 13.8, 'GMX', 2),
#  ('GST', 13.8, 'GMX', 3),
#  ('GST', 13.8, 'GMX', 4),
#  ('GST', 13.8, 'GMX', 6),
#  ('GST', 13.8, 'GMX', 8),
#  ('GST', 13.8, 'GMX', 10),
#  ('GST', 13.8, 'HIT', 1),
#  ('GST', 13.8, 'HIT', 2),
#  ('GST', 13.8, 'HIT', 3),
#  ('GST', 13.8, 'HIT', 4),
#  ('GST', 13.8, 'HIT', 6),
#  ('GST', 13.8, 'HIT', 8),
#  ('GST', 13.8, 'HIT', 10),
#  ('GST', 13.8, 'GE', 1),
#  ('GST', 13.8, 'GE', 2),
#  ('GST', 13.8, 'GE', 3),
#  ('GST', 13.8, 'GE', 4),
#  ('GST', 13.8, 'GE', 6),
#  ('GST', 13.8, 'GE', 8),
#  ('GST', 13.8, 'GE', 10),
#  ('GST', 13.8, 'ALS', 1),
#  ('GST', 13.8, 'ALS', 2),
#  ('GST', 13.8, 'ALS', 3),
#  ('GST', 13.8, 'ALS', 4),
#  ('GST', 13.8, 'ALS', 6),
#  ('GST', 13.8, 'ALS', 8),
#  ('GST', 13.8, 'ALS', 10),
#  ('GST', 18, 'MIT', 1),
#  ('GST', 18, 'MIT', 2),
#  ('GST', 18, 'MIT', 3),
#  ('GST', 18, 'MIT', 4),
#  ('GST', 18, 'MIT', 6),
#  ('GST', 18, 'MIT', 8),
#  ('GST', 18, 'MIT', 10),
#  ('GST', 18, 'ANS', 1),
#  ('GST', 18, 'ANS', 2),
#  ('GST', 18, 'ANS', 3),
#  ('GST', 18, 'ANS', 4),
#  ('GST', 18, 'ANS', 6),
#  ('GST', 18, 'ANS', 8),
#  ('GST', 18, 'ANS', 10),
#  ('GST', 18, 'ENG', 1),
#  ('GST', 18, 'ENG', 2),
#  ('GST', 18, 'ENG', 3),
#  ('GST', 18, 'ENG', 4),
#  ('GST', 18, 'ENG', 6),
#  ('GST', 18, 'ENG', 8),
#  ('GST', 18, 'ENG', 10),
#  ('GST', 18, 'OTH', 1),
#  ('GST', 18, 'OTH', 2),
#  ('GST', 18, 'OTH', 3),
#  ('GST', 18, 'OTH', 4),
#  ('GST', 18, 'OTH', 6),
#  ('GST', 18, 'OTH', 8),
#  ('GST', 18, 'OTH', 10),
#  ('GST', 18, 'TOS', 1),
#  ('GST', 18, 'TOS', 2),
#  ('GST', 18, 'TOS', 3),
#  ('GST', 18, 'TOS', 4),
#  ('GST', 18, 'TOS', 6),
#  ('GST', 18, 'TOS', 8),
#  ('GST', 18, 'TOS', 10),
#  ('GST', 18, 'RK', 1),
#  ('GST', 18, 'RK', 2),
#  ('GST', 18, 'RK', 3),
#  ('GST', 18, 'RK', 4),
#  ('GST', 18, 'RK', 6),
#  ('GST', 18, 'RK', 8),
#  ('GST', 18, 'RK', 10),
#  ('GST', 18, 'GMX', 1),
#  ('GST', 18, 'GMX', 2),
#  ('GST', 18, 'GMX', 3),
#  ('GST', 18, 'GMX', 4),
#  ('GST', 18, 'GMX', 6),
#  ('GST', 18, 'GMX', 8),
#  ('GST', 18, 'GMX', 10),
#  ('GST', 18, 'HIT', 1),
#  ('GST', 18, 'HIT', 2),
#  ('GST', 18, 'HIT', 3),
#  ('GST', 18, 'HIT', 4),
#  ('GST', 18, 'HIT', 6),
#  ('GST', 18, 'HIT', 8),
#  ('GST', 18, 'HIT', 10),
#  ('GST', 18, 'GE', 1),
#  ('GST', 18, 'GE', 2),
#  ('GST', 18, 'GE', 3),
#  ('GST', 18, 'GE', 4),
#  ('GST', 18, 'GE', 6),
#  ('GST', 18, 'GE', 8),
#  ('GST', 18, 'GE', 10),
#  ('GST', 18, 'ALS', 1),
#  ('GST', 18, 'ALS', 2),
#  ('GST', 18, 'ALS', 3),
#  ('GST', 18, 'ALS', 4),
#  ('GST', 18, 'ALS', 6),
#  ('GST', 18, 'ALS', 8),
#  ('GST', 18, 'ALS', 10),
#  ('UST', 6.9, 'MIT', 1),
#  ('UST', 6.9, 'MIT', 2),
#  ('UST', 6.9, 'MIT', 3),
#  ('UST', 6.9, 'MIT', 4),
#  ('UST', 6.9, 'MIT', 6),
#  ('UST', 6.9, 'MIT', 8),
#  ('UST', 6.9, 'MIT', 10),
#  ('UST', 6.9, 'ANS', 1),
#  ('UST', 6.9, 'ANS', 2),
#  ('UST', 6.9, 'ANS', 3),
#  ('UST', 6.9, 'ANS', 4),
#  ('UST', 6.9, 'ANS', 6),
#  ('UST', 6.9, 'ANS', 8),
#  ('UST', 6.9, 'ANS', 10),
#  ('UST', 6.9, 'ENG', 1),
#  ('UST', 6.9, 'ENG', 2),
#  ('UST', 6.9, 'ENG', 3),
#  ('UST', 6.9, 'ENG', 4),
#  ('UST', 6.9, 'ENG', 6),
#  ('UST', 6.9, 'ENG', 8),
#  ('UST', 6.9, 'ENG', 10),
#  ('UST', 6.9, 'OTH', 1),
#  ('UST', 6.9, 'OTH', 2),
#  ('UST', 6.9, 'OTH', 3),
#  ('UST', 6.9, 'OTH', 4),
#  ('UST', 6.9, 'OTH', 6),
#  ('UST', 6.9, 'OTH', 8),
#  ('UST', 6.9, 'OTH', 10),
#  ('UST', 6.9, 'TOS', 1),
#  ('UST', 6.9, 'TOS', 2),
#  ('UST', 6.9, 'TOS', 3),
#  ('UST', 6.9, 'TOS', 4),
#  ('UST', 6.9, 'TOS', 6),
#  ('UST', 6.9, 'TOS', 8),
#  ('UST', 6.9, 'TOS', 10),
#  ('UST', 6.9, 'RK', 1),
#  ('UST', 6.9, 'RK', 2),
#  ('UST', 6.9, 'RK', 3),
#  ('UST', 6.9, 'RK', 4),
#  ('UST', 6.9, 'RK', 6),
#  ('UST', 6.9, 'RK', 8),
#  ('UST', 6.9, 'RK', 10),
#  ('UST', 6.9, 'GMX', 1),
#  ('UST', 6.9, 'GMX', 2),
#  ('UST', 6.9, 'GMX', 3),
#  ('UST', 6.9, 'GMX', 4),
#  ('UST', 6.9, 'GMX', 6),
#  ('UST', 6.9, 'GMX', 8),
#  ('UST', 6.9, 'GMX', 10),
#  ('UST', 6.9, 'HIT', 1),
#  ('UST', 6.9, 'HIT', 2),
#  ('UST', 6.9, 'HIT', 3),
#  ('UST', 6.9, 'HIT', 4),
#  ('UST', 6.9, 'HIT', 6),
#  ('UST', 6.9, 'HIT', 8),
#  ('UST', 6.9, 'HIT', 10),
#  ('UST', 6.9, 'GE', 1),
#  ('UST', 6.9, 'GE', 2),
#  ('UST', 6.9, 'GE', 3),
#  ('UST', 6.9, 'GE', 4),
#  ('UST', 6.9, 'GE', 6),
#  ('UST', 6.9, 'GE', 8),
#  ('UST', 6.9, 'GE', 10),
#  ('UST', 6.9, 'ALS', 1),
#  ('UST', 6.9, 'ALS', 2),
#  ('UST', 6.9, 'ALS', 3),
#  ('UST', 6.9, 'ALS', 4),
#  ('UST', 6.9, 'ALS', 6),
#  ('UST', 6.9, 'ALS', 8),
#  ('UST', 6.9, 'ALS', 10),
#  ('UST', 13.8, 'MIT', 1),
#  ('UST', 13.8, 'MIT', 2),
#  ('UST', 13.8, 'MIT', 3),
#  ('UST', 13.8, 'MIT', 4),
#  ('UST', 13.8, 'MIT', 6),
#  ('UST', 13.8, 'MIT', 8),
#  ('UST', 13.8, 'MIT', 10),
#  ('UST', 13.8, 'ANS', 1),
#  ('UST', 13.8, 'ANS', 2),
#  ('UST', 13.8, 'ANS', 3),
#  ('UST', 13.8, 'ANS', 4),
#  ('UST', 13.8, 'ANS', 6),
#  ('UST', 13.8, 'ANS', 8),
#  ('UST', 13.8, 'ANS', 10),
#  ('UST', 13.8, 'ENG', 1),
#  ('UST', 13.8, 'ENG', 2),
#  ('UST', 13.8, 'ENG', 3),
#  ('UST', 13.8, 'ENG', 4),
#  ('UST', 13.8, 'ENG', 6),
#  ('UST', 13.8, 'ENG', 8),
#  ('UST', 13.8, 'ENG', 10),
#  ('UST', 13.8, 'OTH', 1),
#  ('UST', 13.8, 'OTH', 2),
#  ('UST', 13.8, 'OTH', 3),
#  ('UST', 13.8, 'OTH', 4),
#  ('UST', 13.8, 'OTH', 6),
#  ('UST', 13.8, 'OTH', 8),
#  ('UST', 13.8, 'OTH', 10),
#  ('UST', 13.8, 'TOS', 1),
#  ('UST', 13.8, 'TOS', 2),
#  ('UST', 13.8, 'TOS', 3),
#  ('UST', 13.8, 'TOS', 4),
#  ('UST', 13.8, 'TOS', 6),
#  ('UST', 13.8, 'TOS', 8),
#  ('UST', 13.8, 'TOS', 10),
#  ('UST', 13.8, 'RK', 1),
#  ('UST', 13.8, 'RK', 2),
#  ('UST', 13.8, 'RK', 3),
#  ('UST', 13.8, 'RK', 4),
#  ('UST', 13.8, 'RK', 6),
#  ('UST', 13.8, 'RK', 8),
#  ('UST', 13.8, 'RK', 10),
#  ('UST', 13.8, 'GMX', 1),
#  ('UST', 13.8, 'GMX', 2),
#  ('UST', 13.8, 'GMX', 3),
#  ('UST', 13.8, 'GMX', 4),
#  ('UST', 13.8, 'GMX', 6),
#  ('UST', 13.8, 'GMX', 8),
#  ('UST', 13.8, 'GMX', 10),
#  ('UST', 13.8, 'HIT', 1),
#  ('UST', 13.8, 'HIT', 2),
#  ('UST', 13.8, 'HIT', 3),
#  ('UST', 13.8, 'HIT', 4),
#  ('UST', 13.8, 'HIT', 6),
#  ('UST', 13.8, 'HIT', 8),
#  ('UST', 13.8, 'HIT', 10),
#  ('UST', 13.8, 'GE', 1),
#  ('UST', 13.8, 'GE', 2),
#  ('UST', 13.8, 'GE', 3),
#  ('UST', 13.8, 'GE', 4),
#  ('UST', 13.8, 'GE', 6),
#  ('UST', 13.8, 'GE', 8),
#  ('UST', 13.8, 'GE', 10),
#  ('UST', 13.8, 'ALS', 1),
#  ('UST', 13.8, 'ALS', 2),
#  ('UST', 13.8, 'ALS', 3),
#  ('UST', 13.8, 'ALS', 4),
#  ('UST', 13.8, 'ALS', 6),
#  ('UST', 13.8, 'ALS', 8),
#  ('UST', 13.8, 'ALS', 10),
#  ('UST', 18, 'MIT', 1),
#  ('UST', 18, 'MIT', 2),
#  ('UST', 18, 'MIT', 3),
#  ('UST', 18, 'MIT', 4),
#  ('UST', 18, 'MIT', 6),
#  ('UST', 18, 'MIT', 8),
#  ('UST', 18, 'MIT', 10),
#  ('UST', 18, 'ANS', 1),
#  ('UST', 18, 'ANS', 2),
#  ('UST', 18, 'ANS', 3),
#  ('UST', 18, 'ANS', 4),
#  ('UST', 18, 'ANS', 6),
#  ('UST', 18, 'ANS', 8),
#  ('UST', 18, 'ANS', 10),
#  ('UST', 18, 'ENG', 1),
#  ('UST', 18, 'ENG', 2),
#  ('UST', 18, 'ENG', 3),
#  ('UST', 18, 'ENG', 4),
#  ('UST', 18, 'ENG', 6),
#  ('UST', 18, 'ENG', 8),
#  ('UST', 18, 'ENG', 10),
#  ('UST', 18, 'OTH', 1),
#  ('UST', 18, 'OTH', 2),
#  ('UST', 18, 'OTH', 3),
#  ('UST', 18, 'OTH', 4),
#  ('UST', 18, 'OTH', 6),
#  ('UST', 18, 'OTH', 8),
#  ('UST', 18, 'OTH', 10),
#  ('UST', 18, 'TOS', 1),
#  ('UST', 18, 'TOS', 2),
#  ('UST', 18, 'TOS', 3),
#  ('UST', 18, 'TOS', 4),
#  ('UST', 18, 'TOS', 6),
#  ('UST', 18, 'TOS', 8),
#  ('UST', 18, 'TOS', 10),
#  ('UST', 18, 'RK', 1),
#  ('UST', 18, 'RK', 2),
#  ('UST', 18, 'RK', 3),
#  ('UST', 18, 'RK', 4),
#  ('UST', 18, 'RK', 6),
#  ('UST', 18, 'RK', 8),
#  ('UST', 18, 'RK', 10),
#  ('UST', 18, 'GMX', 1),
#  ('UST', 18, 'GMX', 2),
#  ('UST', 18, 'GMX', 3),
#  ('UST', 18, 'GMX', 4),
#  ('UST', 18, 'GMX', 6),
#  ('UST', 18, 'GMX', 8),
#  ('UST', 18, 'GMX', 10),
#  ('UST', 18, 'HIT', 1),
#  ('UST', 18, 'HIT', 2),
#  ('UST', 18, 'HIT', 3),
#  ('UST', 18, 'HIT', 4),
#  ('UST', 18, 'HIT', 6),
#  ('UST', 18, 'HIT', 8),
#  ('UST', 18, 'HIT', 10),
#  ('UST', 18, 'GE', 1),
#  ('UST', 18, 'GE', 2),
#  ('UST', 18, 'GE', 3),
#  ('UST', 18, 'GE', 4),
#  ('UST', 18, 'GE', 6),
#  ('UST', 18, 'GE', 8),
#  ('UST', 18, 'GE', 10),
#  ('UST', 18, 'ALS', 1),
#  ('UST', 18, 'ALS', 2),
#  ('UST', 18, 'ALS', 3),
#  ('UST', 18, 'ALS', 4),
#  ('UST', 18, 'ALS', 6),
#  ('UST', 18, 'ALS', 8),
#  ('UST', 18, 'ALS', 10)]

# %%
def obtener_datos_por_combinacion(_df, combinacion):
    # Filtrar el DataFrame según la combinación actual
    filtro = (_df['group_number'] == combinacion[0]) & \
             (_df['stator_kv'] == combinacion[1]) & \
             (_df['mfr'] == combinacion[2])

    datos_filtrados = _df[filtro]

    # Crear un objeto con la estructura deseada
    objeto = {
        "family": f"{combinacion[0]}_{combinacion[1]}_{combinacion[2]}_{combinacion[3]}",
        "df": datos_filtrados.to_dict(orient='records')  # Convertir DataFrame a lista de diccionarios
    }

    return objeto

# %%
def filtrar_objetos_con_datos(array_objetos):
    # Array para guardar los objetos filtrados
    objetos_filtrados = []

    # Iterar a través de cada objeto en el array
    for objeto in array_objetos:
        # Verificar si el campo 'df' del objeto tiene longitud mayor a 0
        if len(objeto['df']) > 0:
            # Agregar el objeto al array de objetos filtrados
            objetos_filtrados.append(objeto)

    # Retornar el array de objetos filtrados
    return objetos_filtrados

# %%
# Crear una lista de objetos con los datos filtrados
objetos_datos = [obtener_datos_por_combinacion(df, combinacion) for combinacion in combinaciones]

print("Tamaño de la lista de objetos_datos:", len(objetos_datos))

# Imprimir la lista de objetos
# Obtener el DataFrame del primer objeto en la lista
#df_del_primer_objeto = pd.DataFrame(objetos_datos[0]["df"])
#df_del_primer_objeto
# Out:
# Tamaño de la lista de objetos_datos: 420

# %%
#
resultados_filtrados = filtrar_objetos_con_datos(objetos_datos)

# %%
#resultados_filtrados[0]
print("Tamaño de la lista de objetos_datos:", len(resultados_filtrados))
# Out:
# Tamaño de la lista de objetos_datos: 182

# %% [markdown]
# # **Modelo 1 - Clasificación No supervisada - k-Means**

# %%
def realizar_clustering(Y, random_state=42):
    # Convertir la lista de diccionarios en un DataFrame de Pandas
    Y = pd.DataFrame(Y)
    # Seleccionar columnas
    Y = Y[['test_kv', 'ma']]

    # Dividir los datos en conjuntos de entrenamiento, validación y prueba
    Y_train, Y_temp, _, _ = train_test_split(Y, Y, test_size=0.3, random_state=random_state)
    Y_val, Y_test, _, _ = train_test_split(Y_temp, Y_temp, test_size=0.5, random_state=random_state)

    # Normalizar los datos
    scaler = StandardScaler()
    Y_train_scaled = scaler.fit_transform(Y_train)
    Y_val_scaled = scaler.transform(Y_val)
    Y_test_scaled = scaler.transform(Y_test)

    # Definir el rango de hiperparámetros a ensayar
    param_grid = {
        'n_clusters': [4, 5, 6],
        'init': ['k-means++', 'random'],
        'max_iter': [100, 200, 300],
        'n_init': [10, 15, 20],
        'tol': [1e-4, 1e-5, 1e-6]
    }

    # Inicialización del modelo de KMeans
    kmeans_model = KMeans(random_state=random_state)

    # Configuración de búsqueda de hiperparámetros con validación cruzada
    grid_search = GridSearchCV(kmeans_model, param_grid, cv=5, scoring='neg_mean_squared_error')

    # Ajuste del modelo a los datos
    grid_search.fit(Y)

    return grid_search

# %%
def entrenar_kmeans_y_visualizar(_X, num_clusters=4, init='k-means++', n_init=10, random_state=42, tol=0.0001):
    # Inicializar y ajustar el modelo k-Means
    kmeans_model = KMeans(n_clusters=num_clusters, init=init, n_init=n_init, random_state=random_state, tol=tol)
    _Xa = _X.copy()  # Crear una copia para evitar modificar el DataFrame original
    _Xa['qual'] = kmeans_model.fit_predict(_Xa)

    # Ordenar los centroides por la columna 'ma' (suponiendo que es la segunda columna de características)
    ordered_indices = kmeans_model.cluster_centers_[:, 1].argsort()

    # Crear un mapeo de las etiquetas originales a las etiquetas ordenadas
    label_mapping = {old_label: new_label for new_label, old_label in enumerate(ordered_indices)}

    # Reasignar las etiquetas en el DataFrame según el nuevo mapeo
    _Xa['qual'] = _Xa['qual'].map(label_mapping)

    return _Xa  # Devolver el DataFrame con la columna 'qual' reasignada

# %%
def visualizar_kmeans(df):
    # Asegurarse de que el DataFrame tiene suficientes columnas para la visualización
    if df.shape[1] < 3:
        print("Se necesitan al menos dos columnas numéricas y una columna 'qual' para la visualización.")
        return

    # Seleccionar las dos primeras columnas numéricas para el gráfico
    columnas_para_grafico = df.select_dtypes(include='number').columns[:2]

    # Crear un gráfico de dispersión
    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=df, x=columnas_para_grafico[0], y=columnas_para_grafico[1], hue='qual', palette='viridis')

    # Mostrar el gráfico
    plt.title('Visualización de Clusters de K-Means')
    plt.xlabel(columnas_para_grafico[0])
    plt.ylabel(columnas_para_grafico[1])
    plt.show()

# %%
def procesar_lista_objetos_D(lista_objetos, max_df_a_procesar=1):
    # Crear una lista vacía para almacenar los resultados
    resultados = []

    for objeto in lista_objetos[:max_df_a_procesar]:
        family = objeto['family']
        df_o = pd.DataFrame(objeto['df'])
        print(f"family::::::: {family}, for realizar_clustering.")

        # Continuar si el DataFrame está vacío
        if df_o.empty:
            print(f"DataFrame vacío para la familia {family}, se omite.")
            continue

        # Procesar el DataFrame
        result_clustering = realizar_clustering(df_o)
        best_params_o = result_clustering.best_params_
        print(f"Mejores hiperparámetros para {family}:", best_params_o['n_clusters'])

        df_o= df_o[['test_kv', 'ma']]

        df_modificado = entrenar_kmeans_y_visualizar(df_o, best_params_o['n_clusters'])

        # Guardar los resultados en la lista
        resultados.append({'family': family, 'df': df_modificado})

    return resultados

# %%
def visualizar_kmeans_list(resultados, num_df_a_visualizar):
    # Asegurarse de que hay suficientes resultados para visualizar
    if len(resultados) < num_df_a_visualizar:
        print(f"Solo hay {len(resultados)} resultados disponibles para visualizar.")
        num_df_a_visualizar = len(resultados)

    for i in range(num_df_a_visualizar):
        df = resultados[i]['df']
        family = resultados[i]['family']

        # Asegurarse de que el DataFrame tiene suficientes columnas para la visualización
        if df.shape[1] < 3:
            print(f"Se necesitan al menos dos columnas numéricas y una columna 'qual' para la visualización en {family}.")
            continue

        # Seleccionar las dos primeras columnas numéricas para el gráfico
        columnas_para_grafico = df.select_dtypes(include='number').columns[:2]

        # Asignar colores consistentes a cada cluster
        colors = {0: 'red', 1: 'blue', 2: 'green', 3: 'purple'}

        # Preparar los datos de colores de los clústeres
        unique_quals = df['qual'].dropna().unique()
        unique_quals.sort()
        color_mapping = {qual: color for qual, color in zip(unique_quals, colors.values())}

        # Crear el gráfico de dispersión
        plt.figure(figsize=(10, 6))

        # Visualizar los clusters
        for qual in unique_quals:
            cluster_data = df[df['qual'] == qual]
            plt.scatter(cluster_data[columnas_para_grafico[0]], cluster_data[columnas_para_grafico[1]],
                        color=color_mapping[qual], label=f'Cluster {int(qual)}', alpha=0.5)

        plt.xlabel(columnas_para_grafico[0])
        plt.ylabel(columnas_para_grafico[1])
        plt.title(f'Visualización de Clusters de K-Means para {family}')
        plt.legend()

        # Mostrar el gráfico
        plt.show()

# Suponiendo que `procesar_lista_objetos_test` es una lista de diccionarios con las claves 'df' y 'family'
# visualizar_kmeans_list(procesar_lista_objetos_test, 5)

# %%
max_df_procesar = 3
procesar_lista_objetos_test = procesar_lista_objetos_D(resultados_filtrados,max_df_procesar)
# Out:
# family::::::: GST_6.9_HIT_1, for realizar_clustering.
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ...
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
# Mejores hiperparámetros para GST_6.9_HIT_3: 4
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning:
#
# Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:952: UserWarning:
#
# One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]

# %%
DF_qual = pd.DataFrame(procesar_lista_objetos_test)
procesar_lista_objetos_test[0]
# Out:
# {'family': 'GST_6.9_HIT_1',
#  'df':       test_kv          ma  qual
#  0    0.999472  829.838455     3
#  1    1.999234  832.429588     3
#  2    3.000461  834.593952     3
#  3    3.999918  836.803854     3
#  4    0.999471  827.815175     3
#  ..        ...         ...   ...
#  248  4.001000  786.260000     1
#  249  1.001000  786.400000     1
#  250  2.002000  788.320000     1
#  251  3.002000  789.650000     1
#  252  4.000000  790.070000     1
#
#  [253 rows x 3 columns]}

# %%
# Suponiendo que `resultados` es la lista de objetos con los diccionarios como en tu ejemplo
def crear_tabla_con_familias(resultados):
    # Crear una lista para almacenar los DataFrames con la nueva columna 'family'
    dfs_con_family = []

    # Iterar sobre cada resultado y agregar la columna 'family'
    for resultado in resultados:
        df = resultado['df'].copy()  # Hacer una copia para no modificar el original
        df['family'] = resultado['family']  # Agregar la columna 'family'
        dfs_con_family.append(df)

    # Concatenar todos los DataFrames en uno solo
    df_final = pd.concat(dfs_con_family, ignore_index=True)

    return df_final

# %%
# Usar la función y guardar el DataFrame resultante
df_con_familias = crear_tabla_con_familias(procesar_lista_objetos_test)  # 'resultados' debe ser tu lista de objetos
df_con_familias

# Exportar el DataFrame a un archivo CSV
#nombre_archivo = '/content/gdrive/MyDrive/Colab Notebooks/Proyecto_integradorA/df_con_familiasFull.csv'
#df_con_familias.to_csv(nombre_archivo, index=False)
# Out:
#       test_kv          ma  qual         family
# 0    0.999472  829.838455     3  GST_6.9_HIT_1
# 1    1.999234  832.429588     3  GST_6.9_HIT_1
# 2    3.000461  834.593952     3  GST_6.9_HIT_1
# 3    3.999918  836.803854     3  GST_6.9_HIT_1
# 4    0.999471  827.815175     3  GST_6.9_HIT_1
# ..        ...         ...   ...            ...
# 754  4.001000  786.260000     1  GST_6.9_HIT_3
# 755  1.001000  786.400000     1  GST_6.9_HIT_3
# 756  2.002000  788.320000     1  GST_6.9_HIT_3
# 757  3.002000  789.650000     1  GST_6.9_HIT_3
# 758  4.000000  790.070000     1  GST_6.9_HIT_3
#
# [759 rows x 4 columns]

# %%
visualizar_kmeans_list(procesar_lista_objetos_test,3)
